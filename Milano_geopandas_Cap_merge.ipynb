# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoneFinessi/geopandas/blob/main/Milano_geopandas_Cap_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install geopandas matplotlib pandas contextily

# %%
import geopandas as gpd
import matplotlib as plt
import pandas as pd
import contextily as ctx

# %%
df=gpd.read_file("https://raw.githubusercontent.com/SimoneFinessi/Dati/main/Redditi_e_principali_variabili_IRPEF_su_base_subcomunale_CSV_2021.csv",index=0)

# %%
milano=df[df["Denominazione Comune"]== "MILANO"]
milano.head(1)

# %%
milano.head(1)

# %%
milano=milano.drop("geometry",axis=1)

# %%
milano["rredditoT"]=milano["Reddito complessivo da 0 a 10000 euro - Ammontare in euro"].astype(int)+milano["Reddito complessivo da 10000 a 15000 euro - Ammontare in euro"].astype(int)+milano["Reddito complessivo da 15000 a 26000 euro - Ammontare in euro"].astype(int)+milano["Reddito complessivo da 26000 a 55000 euro - Ammontare in euro"].astype(int)+milano["Reddito complessivo da 55000 a 75000 euro - Ammontare in euro"].astype(int)+milano["Reddito complessivo da 75000 a 120000 euro - Ammontare in euro"].astype(int)+milano["Reddito complessivo oltre 120000 euro - Ammontare in euro"].astype(int)

# %%
finale=quar2.merge(milano,on="CAP")
finale

# %%
finale.plot()
# Out:
# <Axes: >

# %%
quar=gpd.read_file("https://raw.githubusercontent.com/SimoneFinessi/Dati/main/cap_di_milano.geojson",driver="GeoJSON")

# %%
quar2=gpd.read_file("https://github.com/SimoneFinessi/Dati/raw/main/banchedati-cap-zone-demo-database%20(1).zip")

# %%
quar2.plot(figsize=(12,12),edgecolor="Black")

# %%
quar.plot(figsize=(12,12),edgecolor="Black")
